# %%
import requests
import pandas as pd
import nltk
import numpy as np
from nltk.corpus import wordnet
import re

# %% [markdown]
# ## Synonyms with Thesaurus API

# %%
def get_synonyms_api(key_word):
    url = "https://www.dictionaryapi.com/api/v3/references/thesaurus/json/"
    key= "?key=bc125025-b3b8-4b13-b8e8-c1ef37845bad"
    syn_json = requests.get(url+key_word.lower()+key).json()
    syn_list = syn_json[0]['meta']['syns']
    if len(syn_list) > 1:
        master = sum(syn_list, [])
    elif len(syn_list) == 1:
        master = syn_list[0]
    master.append(key_word)
    return master

# %% [markdown]
# ### Problems with some words
#
# consumer discretionary, consumer staples, communication services (DO NOT WORK)
#
#     -> they do not exist within the Thesaurus, therefore the JSON returns a list with possible words
# Definition of Consumer Discretionary:
# - goods that are non-essential but desirable if their income is sufficient to purchase them
#
# Definition of Consumer Staples:
# - goods that are essential
#
# Definition of Communication Services:
# - elecommunications Services, Cable Services, Video Services, or Information Services
#
# -> Solution for now: remove those words from here

# %%
df = pd.read_csv("master_taxonomy.csv", index_col=0)#, on_bad_lines='skip')
df.columns
# Out:
# Index(['Authors', 'Title', 'DOI', 'Link', 'Abstract', 'Author Keywords',
#        'Index Keywords'],
#       dtype='object')

# %%
df['Abstract'] = df['Abstract'].str.lower()
df['Title'] = df['Title'].str.lower()
df['Author Keywords'] = df['Author Keywords'].str.lower()
df['Index Keywords'] = df['Index Keywords'].str.lower()

# %%
df = df.fillna("blank")

# %%
non_alp = [';', ',', '(', ')', '[', ']', '.']
for i in non_alp:
    for col in ['Title','Abstract', 'Author Keywords', 'Index Keywords']:
        df[col] = df[col].map(lambda x: x.replace(i,''))

# %%
df['content_sum'] = df['Abstract'] + df['Title'] + df['Author Keywords'] + df['Index Keywords']
df["content_sum"] = df["content_sum"].str.lower()
#df['content_sum'].values[0].split()

# %%
keys = ["energy", "materials", "industrial", "financial",  "utilities"]
no_keys = [ "consumer discretionary", "consumer staples", "information technology", "communication services", "healthcare", "real estate"]

# %%
# Saving into a dictionary all of the syns
keys_dict = {}
for i in keys:
    keys_dict[i] = get_synonyms_api(i)
 
keys_dict
# Out:
# {'energy': ['aura',
#   'chi',
#   'ki',
#   'vibe(s)',
#   'vibration(s)',
#   'beans',
#   'bounce',
#   'brio',
#   'dash',
#   'drive',
#   'dynamism',
#   'esprit',
#   'gas',
#   'get-up-and-go',
#   'ginger',
#   'go',
#   'gusto',
#   'hardihood',
#   'juice',
#   'life',
#   'moxie',
#   'oomph',
#   'pep',
#   'punch',
#   'sap',
#   'snap',
#   'starch',
#   'verve',
#   'vigor',
#   'vim',
#   'vinegar',
#   'vitality',
#   'zing',
#   'zip',
#   'fuel',
#   'power',
#   'firepower',
#   'force',
#   'horsepower',
#   'might',
#   'muscle',
#   'potence',
#   'potency',
#   'power',
#   'puissance',
#   'sinew',
#   'strength',
#   'vigor',
#   'energy'],
#  'materials': ['accoutrements',
#   'apparatus',
#   'equipment',
#   'gear',
#   'hardware',
#   'kit',
#   'matériel',
#   'outfit',
#   'paraphernalia',
#   'stuff',
#   'tackle',
#   'materials'],
#  'industrial': ['mechanical',
#   'fabricated',
#   'manufactured',
#   'cultivated',
#   'processed',
#   'refined',
#   'artificial',
#   'man-made',
#   'nonnatural',
#   'synthetic',
#   'ersatz',
#   'faux',
#   'imitation',
#   'industrial'],
#  'financial': ['dollars-and-cents',
#   'fiscal',
#   'monetary',
#   'pecuniary',
#   'pocket',
#   'financial'],
#  'utilities': ['account',
#   'avail',
#   'mileage',
#   'service',
#   'serviceability',
#   'serviceableness',
#   'use',
#   'usefulness',
#   'utilities']}

# %%
matches = re.findall("explainable artificial intelligence", " ".join(df['content_sum'].values[0].split()))
matches
#print(" ".join(df['content_sum'].values[0].split()))
# Out:
# ['explainable artificial intelligence', 'explainable artificial intelligence']

# %%
for key in keys_dict:
    df[key] = 0
    
    for phr in get_synonyms_api(key):
        for i in range(len(df)+1):
            df.loc[i, key] += len(re.findall(str(phr), " ".join(df['content_sum'].values[i].split())))
            
            
           # if phr in (df['content_sum'].values[i].split()):
            #    df[key][i] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3799             try:
# -> 3800                 return self._engine.get_loc(casted_key)
#    3801             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 4591
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/l4/pbw5dk1139gdk7nt6gdt2yp40000gn/T/ipykernel_1957/4041482387.py in <module>
#       4     for phr in get_synonyms_api(key):
#       5         for i in range(len(df)+1):
# ----> 6             df.loc[i, key] += len(re.findall(str(phr), " ".join(df['content_sum'].values[i].split())))
#       7
#       8
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1066             if self._is_scalar_access(key):
#    1067                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068             return self._getitem_tuple(key)
#    1069         else:
#    1070             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1246         with suppress(IndexingError):
#    1247             tup = self._expand_ellipsis(tup)
# -> 1248             return self._getitem_lowerdim(tup)
#    1249
#    1250         # no multi-index, so validate all of the indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     966                 # We don't need to check for tuples here because those are
#     967                 #  caught by the _is_nested_tuple_indexer check above.
# --> 968                 section = self._getitem_axis(key, axis=i)
#     969
#     970                 # We should never have a scalar section here, because
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1311         # fall thru to straight lookup
#    1312         self._validate_key(key, axis)
# -> 1313         return self._get_label(key, axis=axis)
#    1314
#    1315     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1259     def _get_label(self, label, axis: int):
#    1260         # GH#5567 this will fail if the label is not present in the axis.
# -> 1261         return self.obj.xs(label, axis=axis)
#    1262
#    1263     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4055                     new_index = index[loc]
#    4056         else:
# -> 4057             loc = index.get_loc(key)
#    4058
#    4059             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3800                 return self._engine.get_loc(casted_key)
#    3801             except KeyError as err:
# -> 3802                 raise KeyError(key) from err
#    3803             except TypeError:
#    3804                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 4591

# %%
df
# Out:
#                                                 Authors  \
# 0     Abadía J.J.P., Fritz H., Dadoulis G., Dragos K...
# 1                              Abbass H.A., Hunjet R.A.
# 2                              Abdollahi A., Pradhan B.
# 3     Abdul A., Von Der Weth C., Kankanhalli M., Lim...
# 4           Abe T., Furukawa R., Iwasaki Y., Ikemura T.
# ...                                                 ...
# 1414                         [No author name available]
# 1415                         [No author name available]
# 1416                         [No author name available]
# 1421                         [No author name available]
# 1427                         [No author name available]
#
#                                                   Title  \
# 0     automated decision making in structural health...
# 1     smart shepherding: towards transparent artific...
# 2     urban vegetation mapping from aerial imagery u...
# 3     cogam: measuring and moderating cognitive load...
# 4     time-series trend of pandemic sars-cov-2 varia...
# ...                                                 ...
# 1414  icmlsc 2021 - proceedings of the 2021 5th inte...
# 1415  2021 ieee 29th international conference on net...
# 1416  10th international conference on computational...
# 1421  proceedings of the 2nd international conferenc...
# 1427  15th international conference on soft computin...
#
#                               DOI  \
# 0                           blank
# 1     10.1007/978-3-030-60898-9_1
# 2               10.3390/s21144738
# 3         10.1145/3313831.3376615
# 4            10.5334/dsj-2021-029
# ...                           ...
# 1414                        blank
# 1415                        blank
# 1416                        blank
# 1421                        blank
# 1427                        blank
#
#                                                    Link  \
# 0     https://www.scopus.com/inward/record.uri?eid=2...
# 1     https://www.scopus.com/inward/record.uri?eid=2...
# 2     https://www.scopus.com/inward/record.uri?eid=2...
# 3     https://www.scopus.com/inward/record.uri?eid=2...
# 4     https://www.scopus.com/inward/record.uri?eid=2...
# ...                                                 ...
# 1414  https://www.scopus.com/inward/record.uri?eid=2...
# 1415  https://www.scopus.com/inward/record.uri?eid=2...
# 1416  https://www.scopus.com/inward/record.uri?eid=2...
# 1421  https://www.scopus.com/inward/record.uri?eid=2...
# 1427  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                                Abstract  \
# 0     the need for processing large amounts of data ...
# 1     the aim of this chapter is to uncover the beau...
# 2     urban vegetation mapping is critical in many a...
# 3     interpretable machine learning models trade -o...
# 4     to confront the global threat of coronavirus d...
# ...                                                 ...
# 1414  the proceedings contain 32 papers the topics d...
# 1415  the proceedings contain 75 papers the topics d...
# 1416  the proceedings contain 33 papers the special ...
# 1421  the proceedings contain 21 papers the topics d...
# 1427  the proceedings contain 83 papers the special ...
#
#                                         Author Keywords  \
# 0                                                 blank
# 1     explainable artificial intelligence interpreta...
# 2     deep neural network remote sensing shap vegeta...
# 3     cognitive load explainable artificial intellig...
# 4     batch-learning self-organizing map blsom covid...
# ...                                                 ...
# 1414                                              blank
# 1415                                              blank
# 1416                                              blank
# 1421                                              blank
# 1427                                              blank
#
#                                          Index Keywords  \
# 0     artificial intelligence damage detection decis...
# 1                                                 blank
# 2     aerial photography antennas biodiversity deep ...
# 3     computation theory economic and social effects...
# 4     conformal mapping diseases genes machine learn...
# ...                                                 ...
# 1414                                              blank
# 1415                                              blank
# 1416                                              blank
# 1421                                              blank
# 1427                                              blank
#
#                                             content_sum  energy  materials  \
# 0     the need for processing large amounts of data ...   28734        585
# 1     the aim of this chapter is to uncover the beau...   28734        585
# 2     urban vegetation mapping is critical in many a...   28734        585
# 3     interpretable machine learning models trade -o...   28734        585
# 4     to confront the global threat of coronavirus d...   28734        585
# ...                                                 ...     ...        ...
# 1414  the proceedings contain 32 papers the topics d...   28734        585
# 1415  the proceedings contain 75 papers the topics d...   28734        585
# 1416  the proceedings contain 33 papers the special ...   28734        585
# 1421  the proceedings contain 21 papers the topics d...   28734        585
# 1427  the proceedings contain 83 papers the special ...   28734        585
#
#       industrial  financial  utilities
# 0           7592        295       9683
# 1           7592        295       9683
# 2           7592        295       9683
# 3           7592        295       9683
# 4           7592        295       9683
# ...          ...        ...        ...
# 1414        7592        295       9683
# 1415        7592        295       9683
# 1416        7592        295       9683
# 1421        7592        295       9683
# 1427        7592        295       9683
#
# [4591 rows x 13 columns]

# %%
'''
keys_dict["consumer discretionary"] = ["non-essential goods", "non essential goods", "non-essential products", "non essential products", "unrestricted goods", "unrestricted products", "nonobligatory goods", "nonobligatory products"]
keys_dict["consumer staples"] = ["essential goods", "essential goods", "essential products", "essential products", "restricted goods", "restricted products", "obligatory goods", "obligatory products"]
keys_dict["information technology"] = ["products", "heloo"]
keys_dict["communication services"] = ["products", "heloo"]
keys_dict["healthcare"] = ["products", "heloo"]
keys_dict["real estate"] = ["products", "heloo"]
'''
# Out:
# '\nkeys_dict["consumer discretionary"] = ["non-essential goods", "non essential goods", "non-essential products", "non essential products", "unrestricted goods", "unrestricted products", "nonobligatory goods", "nonobligatory products"]\nkeys_dict["consumer staples"] = ["essential goods", "essential goods", "essential products", "essential products", "restricted goods", "restricted products", "obligatory goods", "obligatory products"]\nkeys_dict["information technology"] = ["products", "heloo"]\nkeys_dict["communication services"] = ["products", "heloo"]\nkeys_dict["healthcare"] = ["products", "heloo"]\nkeys_dict["real estate"] = ["products", "heloo"]\n'

# %%
for key in keys_dict:
    df[key] = 0
    
    for phr in get_synonyms_api(key):
        for i in range(len(df)): 
            if phr in (df['content_sum'].values[i].split()):
                df[key][i] += 1
# Out:
# /var/folders/l4/pbw5dk1139gdk7nt6gdt2yp40000gn/T/ipykernel_1957/599690671.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[key][i] += 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3799             try:
# -> 3800                 return self._engine.get_loc(casted_key)
#    3801             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 2086
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/l4/pbw5dk1139gdk7nt6gdt2yp40000gn/T/ipykernel_1957/599690671.py in <module>
#       5         for i in range(len(df)):
#       6             if phr in (df['content_sum'].values[i].split()):
# ----> 7                 df[key][i] += 1
#       8
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     980
#     981         elif key_is_scalar:
# --> 982             return self._get_value(key)
#     983
#     984         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1090
#    1091         # Similar to Index.get_value, but we do not fall back to positional
# -> 1092         loc = self.index.get_loc(label)
#    1093         return self.index._get_values_for_loc(self, loc, label)
#    1094
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3800                 return self._engine.get_loc(casted_key)
#    3801             except KeyError as err:
# -> 3802                 raise KeyError(key) from err
#    3803             except TypeError:
#    3804                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 2086

# %%
for m in range(len(df)):
    df['master_content_sum'] = " "
    for i in df['content_sum'].values[m].split():
        for j in df['content_sum'].values[m].split():
            df.iloc[m, -1] = [i + " " + j]
            #df['master_content_sum'][m].append()

# %%
for key in key_words:
    df[key] = 0
    for phr in get_synonyms(key):
        for i in range(len(df)): 
            if phr in (df['content_sum'].values[i].split()):
                df[key][i] += 1
    #df.loc[key, i] = count
